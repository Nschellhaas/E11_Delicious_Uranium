# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # Step 1:

# %% [markdown]
# c. <br />
# We must not have taken enough data to see a Gaussian distribution since our data isn't symmetrical.

# %%
Out_Time = np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=0)
Out_Particles = np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=1)
Out_Temp = np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=2)
Out_Hum = np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6)
Out_PM2_5 = np.loadtxt('Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=1)
In_Time = np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=0)
In_Particles = np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=1)
In_Temp = np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=2)
In_Hum = np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6)
In_PM2_5 = np.loadtxt('Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=1)
#Particles/Time
plt.figure(figsize=(8,8))
plt.plot(Out_Time,Out_Particles, label="Particles/Time Outside",linestyle='--', color='b')
plt.xlabel(xlabel="Time (seconds)")
plt.ylabel(ylabel="Particles (2.5um/0.1L air)")

plt.plot(In_Time,In_Particles, label="Particles/Time Inside",linestyle='--', color='g')
plt.xlabel(xlabel="Time (seconds)")
plt.ylabel(ylabel="Particles (2.5um/0.1L air)")

plt.legend(loc=2,bbox_to_anchor=(-.2, 1.1))

plt.twinx()
#Temperature/Time
plt.plot(Out_Time,Out_Temp, label="Temp/Time Outside", color='b')
plt.xlabel(xlabel="Time (seconds)")
plt.ylabel(ylabel="Temerature (Celcius)")

plt.plot(In_Time,In_Temp, label="Temp/Time Inside", color = 'g')
plt.xlabel(xlabel="Time (seconds)")
plt.ylabel(ylabel="Temerature (Celcius)")

plt.legend(loc=1, bbox_to_anchor=(1.2, 1.1))

# %%
#Particles Hist
plt.hist([In_Particles,Out_Particles],stacked=True,bins=2,color=['g','b'],label=['Outside Particles', 'Inside Particles'])
plt.xticks(ticks=(0,1))
plt.xlabel(xlabel='Number of particles with a size of 2.5 um per second')
plt.ylabel(ylabel='Count')
plt.title(label="Number of Particles Inside vs Outside")
plt.legend()

# %%
#Temperature Hist
plt.hist([In_Temp,Out_Temp],stacked=True,bins=10,color=['g','b'],label=['Outside Temperature', 'Inside Temperature'])
plt.xlabel(xlabel='Temperature')
plt.ylabel(ylabel='Count')
plt.title(label="Number of Particles Inside vs Outside")
plt.legend()

# %%
# Data Analysis
# 1. Mean
#Particles mean
mean_In_Particles=np.mean(In_Particles)
mean_Out_Particles=np.mean(Out_Particles)
print(f"The mean of the number of inside particles is {mean_In_Particles}")
print(f"The mean of the number of outside particles is {mean_Out_Particles}")
#Particles std
std_In_Particles=np.std(In_Particles)
std_Out_Particles=np.std(Out_Particles)
print(f"The mean standard deviation of the number of inside particles is {std_In_Particles/(299**(1/2))}")
print(f"The mean standard deviation of the number of outside particles is {std_Out_Particles/(299**(1/2))}")

#Temperature mean
mean_In_Temp=np.mean(In_Temp)
mean_Out_Temp=np.mean(Out_Temp)
print(f"The mean of the temperature inside is {mean_In_Temp}")
print(f"The mean of the temperature outside is {mean_Out_Temp}")
#Temperature std
std_In_Temp=np.std(In_Temp)
std_Out_Temp=np.std(Out_Temp)
print(f"The mean standard deviation of temperature inside {std_In_Temp/(299**(1/2))}")
print(f"The mean standard deviation of temperature outside {std_Out_Temp/(299**(1/2))}")
# Out:
# The mean of the number of inside particles is 1.0903010033444815
# The mean of the number of outside particles is 2.688963210702341
# The mean standard deviation of the number of inside particles is 0.07392453435321149
# The mean standard deviation of the number of outside particles is 0.137980583367767
# The mean of the temperature inside is 34.5849866743311
# The mean of the temperature outside is 31.787559704222403
# The mean standard deviation of temperature inside 0.014782979865962973
# The mean standard deviation of temperature outside 0.11120139003415117

# %%
print(f"The variance between the number of particles inside vs outside is {(mean_In_Particles-mean_Out_Particles)/(std_Out_Particles/(299**(1/2)))} standard deviations")
print(f"The variance between the outside vs inside temperature is {(mean_In_Temp-mean_Out_Temp)/(std_Out_Temp/(299**(1/2)))} standard deviations")
# Out:
# The variance between the number of particles inside vs outside is -11.586138921422444 standard deviations
# The variance between the outside vs inside temperature is 25.1564028943305 standard deviations

# %%
#Gas Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3),np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3)],stacked=True,bins=10,color=['g','b'],label=['Inside Gas Value', 'Outside Gas Value'])
plt.xlabel(xlabel='Ohms')
plt.ylabel(ylabel='Frequency')
plt.title(label="Gas Value Inside vs Outside")
plt.legend()

print(f"The mean of inside gas values is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3)),)}")
print(f"The mean of outside gas values is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3)),)}")
print("")
print(f"The mean standard deviation of the number of inside gas values is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3))/(299**(1/2)),)}")
print(f"The mean standard deviation of the number of outside gas values is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3))/(299**(1/2)),)}")



gas_in_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3))
gas_out_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3))

gas_in_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3))
gas_out_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3))
print("")
print(f"The variance between the number of particles inside vs outside is {(gas_in_mean-gas_out_mean)/(gas_out_std/(299**(1/2)))} standard deviations")
# Out:
# The mean of inside gas values is 108950
# The mean of outside gas values is 150794
#
# The mean standard deviation of the number of inside gas values is 1761
# The mean standard deviation of the number of outside gas values is 1156
#
# The variance between the number of particles inside vs outside is -36.19295334814582 standard deviations

# %%
#Pressure Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4),np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4)],stacked=True,bins=10,color=['g','b'],label=['Inside Pressure', 'Outside Pressure'])
plt.xlabel(xlabel='Pascals')
plt.ylabel(ylabel='Frequency')
plt.title(label="Pressure Value Inside vs Outside")
plt.legend()

print(f"The mean of the number of inside pressure is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4)),)}")
print(f"The mean of the number of outside pressure is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4)),)}")
print("")
print(f"The mean standard deviation of the number of inside pressure is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4))/(300**(1/2)),2)}")
print(f"The mean standard deviation of the number of outside pressure is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4))/(299**(1/2)),2)}")

gas_in_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4))
gas_out_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4))

gas_in_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4))
gas_out_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4))

print("")
print(f"The variance between the number of particles inside vs outside is {(gas_in_mean-gas_out_mean)/(gas_out_std/(299**(1/2)))} standard deviations")
# Out:
# The mean of the number of inside pressure is 1005
# The mean of the number of outside pressure is 1003
#
# The mean standard deviation of the number of inside pressure is 0.0
# The mean standard deviation of the number of outside pressure is 0.03
#
# The variance between the number of particles inside vs outside is 88.3807438326625 standard deviations

# %%
#Altitude Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5),np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5)],stacked=True,bins=10,color=['g','b'],label=['Inside Altitude', 'Outside Altitude'])
plt.xlabel(xlabel='Meters')
plt.ylabel(ylabel='Frequency')
plt.title(label="Altitude Value Inside vs Outside")
plt.legend()

print(f"The mean of inside altitude is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5)),)}")
print(f"The mean of outside altitude is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5)),)}")
print("")
print(f"The mean standard deviation of the number of inside altitude is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5)),2)}")
print(f"The mean standard deviation of the number of outside altitude is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5)),2)}")
print("")
print(f"The mean uncertainty of the number of inside altitude is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5))/(299**(1/2)),2)}")
print(f"The mean uncertainty of the number of outside altitude is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5))/(299**(1/2)),2)}")

gas_in_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5))
gas_out_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5))

gas_in_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5))
gas_out_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5))

print("")
print(f"The variance between the number of particles inside vs outside is {(gas_in_mean-gas_out_mean)/(gas_out_std/(299**(1/2)))} standard deviations")
# Out:
# The mean of inside altitude is 68
# The mean of outside altitude is 88
#
# The mean standard deviation of the number of inside altitude is 0.13
# The mean standard deviation of the number of outside altitude is 3.92
#
# The mean uncertainty of the number of inside altitude is 0.01
# The mean uncertainty of the number of outside altitude is 0.23
#
# The variance between the number of particles inside vs outside is -88.31511751355059 standard deviations

# %%
#Humidity Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6),np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6)],stacked=True,bins=10,color=['g','b'],label=['Inside Humidity', 'Outside Humidity'])
plt.xlabel(xlabel='1/1000 %')
plt.ylabel(ylabel='Frequency')
plt.title(label="Humidity Value Inside vs Outside")
plt.legend()

print(f"The mean of the number of inside humidity is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6)),)}")
print(f"The mean of the number of outside humidity is {round(np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6)),)}")
print("")
print(f"The mean standard deviation of the number of inside altitude is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6)),2)}")
print(f"The mean standard deviation of the number of outside altitude is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6)),2)}")
print("")
print(f"The mean uncertainty of the number of inside humidity is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6))/(299**(1/2)),2)}")
print(f"The mean uncertainty of the number of outside humidity is {round(np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6))/(299**(1/2)),2)}")

gas_in_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5))
gas_out_mean = np.mean(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5))

gas_in_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5))
gas_out_std = np.std(np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5))

print("")
print(f"The variance between the number of particles inside vs outside is {(gas_in_mean-gas_out_mean)/(gas_out_std/(299**(1/2)))} standard deviations")
# Out:
# The mean of the number of inside humidity is 20
# The mean of the number of outside humidity is 18
#
# The mean standard deviation of the number of inside altitude is 0.6
# The mean standard deviation of the number of outside altitude is 1.54
#
# The mean uncertainty of the number of inside humidity is 0.03
# The mean uncertainty of the number of outside humidity is 0.09
#
# The variance between the number of particles inside vs outside is -88.31511751355059 standard deviations

# %% [markdown]
# # Step 2:

# %%
#Temperature Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=2),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=10)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Temp Ours', 'Inside Temp Theirs'])
plt.xlabel(xlabel='Celsius')
plt.ylabel(ylabel='Frequency')
plt.title(label="Temperature Value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[47], line 2
#       1 #Temperature Hist Inside vs Outside
# ----> 2 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=2),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=10)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Temp Ours', 'Inside Temp Theirs'])
#       3 plt.xlabel(xlabel='Celsius')
#       4 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
#Temperature Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=2),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=10)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Temp Ours', 'Outside Temp Theirs'])
plt.xlabel(xlabel='Celsius')
plt.ylabel(ylabel='Frequency')
plt.title(label="Temperature Value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 2
#       1 #Temperature Hist Inside vs Outside
# ----> 2 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=2),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=10)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Temp Ours', 'Outside Temp Theirs'])
#       3 plt.xlabel(xlabel='Celsius')
#       4 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
#Gas Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=11)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Gas Ours', 'Inside Gas Theirs'])
plt.xlabel(xlabel='Ohms')
plt.ylabel(ylabel='Frequency')
plt.title(label="Gas Value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 #Gas Hist Inside vs Outside
# ----> 2 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=3),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=11)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Gas Ours', 'Inside Gas Theirs'])
#       3 plt.xlabel(xlabel='Ohms')
#       4 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=11)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Gas Ours', 'Outside Gas Theirs'])
plt.xlabel(xlabel='Ohms')
plt.ylabel(ylabel='Frequency')
plt.title(label="Gas Value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=3),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=11)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Gas Ours', 'Outside Gas Theirs'])
#       2 plt.xlabel(xlabel='Ohms')
#       3 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
#Pressure Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=13)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Pressure Ours', 'Inside Pressure Theirs'])
plt.xlabel(xlabel='Pascals')
plt.ylabel(ylabel='Frequency')
plt.title(label="Pressure Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 2
#       1 #Pressure Hist Inside vs Outside
# ----> 2 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=13)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Pressure Ours', 'Inside Pressure Theirs'])
#       3 plt.xlabel(xlabel='Pascals')
#       4 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=13)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Pressure Ours', 'Outside Pressure Theirs'])
plt.xlabel(xlabel='Pascals')
plt.ylabel(ylabel='Frequency')
plt.title(label="Pressure value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=13)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Pressure Ours', 'Outside Pressure Theirs'])
#       2 plt.xlabel(xlabel='Pascals')
#       3 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
#Altitude Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=14)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Altitude Ours', 'Inside Altitude Theirs'])
plt.xlabel(xlabel='Meters')
plt.ylabel(ylabel='Frequency')
plt.title(label="Altitude Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 2
#       1 #Altitude Hist Inside vs Outside
# ----> 2 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=5),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=14)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Altitude Ours', 'Inside Altitude Theirs'])
#       3 plt.xlabel(xlabel='Meters')
#       4 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=14)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Altitude Ours', 'Outside Altitude Theirs'])
plt.xlabel(xlabel='Meters')
plt.ylabel(ylabel='Frequency')
plt.title(label="Altitude value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=5),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=14)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Altitude Ours', 'Outside Altitude Theirs'])
#       2 plt.xlabel(xlabel='Meters')
#       3 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
#Altitude Hist Inside vs Outside
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=12)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Humidity Ours', 'Inside Humidity Theirs'])
plt.xlabel(xlabel='1/1000%')
plt.ylabel(ylabel='Frequency')
plt.title(label="Humidity Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 #Altitude Hist Inside vs Outside
# ----> 2 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=6),np.loadtxt('E11_Delicious_Uranium/other_group_insidedata.csv', delimiter=',', skiprows=2,usecols=12)],stacked=True,bins=10,color=['g', 'r'],label=['Inside Humidity Ours', 'Inside Humidity Theirs'])
#       3 plt.xlabel(xlabel='1/1000%')
#       4 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=12)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Altitude Ours', 'Outside Altitude Theirs'])
plt.xlabel(xlabel='Meters')
plt.ylabel(ylabel='Frequency')
plt.title(label="Altitude value Inside vs Outside")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 plt.hist([np.loadtxt('E11_Delicious_Uranium/Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=6),np.loadtxt('E11_Delicious_Uranium/other_group_outsidedata.csv', delimiter=',', skiprows=2,usecols=12)],stacked=True,bins=10,color=['b', 'y'],label=['Outside Altitude Ours', 'Outside Altitude Theirs'])
#       2 plt.xlabel(xlabel='Meters')
#       3 plt.ylabel(ylabel='Frequency')
#
# File /srv/conda/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
def Div1_Out(Out_Temp,Out_Hum):
    length = len(Out_Temp)
    Out_Hum_Div1=[]
    Out_Temp_Div1=[]
    for i in range(length-1):
        Out_Hum_Div1.append((Out_Hum[i+1]-Out_Hum[i])/(Out_Temp[i+1]-Out_Temp[i]))
        Out_Temp_Div1.append(Out_Temp[i])
    return Out_Hum_Div1, Out_Temp_Div1
Out_Hum_Div1, Out_Temp_Div1 = Div1_Out(Out_Temp,Out_Hum)
def Div2_Out(Out_Temp_Div1,Out_Hum_Div1):
    length2 = len(Out_Temp_Div1)
    Out_Temp_Div2=[]
    Out_Hum_Div2=[]
    for n in range(length2-1):
        Out_Hum_Div2.append((Out_Hum_Div1[n+1]-Out_Hum_Div1[n])/(Out_Temp_Div1[n+1]-Out_Temp_Div1[n]))
        Out_Temp_Div2.append(Out_Temp_Div1[n])
    return Out_Hum_Div2, Out_Temp_Div2
Out_Hum_Div2, Out_Temp_Div2 = Div2_Out(Out_Temp_Div1,Out_Hum_Div1)
def clean_Out(Out_Temp, Out_Temp_Div2, Out_Hum, Out_Hum_Div2):
    Clean_Error = 1
    length3 = len(Out_Temp_Div2)
    Clean_Out_Hum=[]
    Clean_Out_Temp=[]
    for i in range(length3):
        if abs(Out_Hum_Div2[i])<=100:
            Clean_Out_Hum.append(Out_Hum[i])
            Clean_Out_Temp.append(Out_Temp[i])
        else:
            continue
    return Clean_Out_Temp, Clean_Out_Hum
Clean_Out_Temp, Clean_Out_Hum = clean_Out(Out_Temp, Out_Temp_Div2, Out_Hum, Out_Hum_Div2)

# %%
def Div1_In(In_Temp,In_Hum):
    length = len(In_Temp)
    In_Hum_Div1=[]
    In_Temp_Div1=[]
    for i in range(length-1):
        In_Hum_Div1.append((In_Hum[i+1]-In_Hum[i])/(In_Temp[i+1]-In_Temp[i]))
        In_Temp_Div1.append(In_Temp[i])
    return In_Hum_Div1, In_Temp_Div1
In_Hum_Div1, In_Temp_Div1 = Div1_In(In_Temp,In_Hum)
def Div2_In(In_Temp_Div1,In_Hum_Div1):
    length2 = len(In_Temp_Div1)
    In_Temp_Div2=[]
    In_Hum_Div2=[]
    for n in range(length2-1):
        In_Hum_Div2.append((In_Hum_Div1[n+1]-In_Hum_Div1[n])/(In_Temp_Div1[n+1]-In_Temp_Div1[n]))
        In_Temp_Div2.append(In_Temp_Div1[n])
    return In_Hum_Div2, In_Temp_Div2
In_Hum_Div2, In_Temp_Div2 = Div2_In(In_Temp_Div1,In_Hum_Div1)
def clean_In(In_Temp, In_Temp_Div2, In_Hum, In_Hum_Div2):
    Clean_Error = 1
    length3 = len(In_Temp_Div2)
    Clean_In_Hum=[]
    Clean_In_Temp=[]
    for i in range(length3):
        if abs(In_Hum_Div2[i])<=100:
            Clean_In_Hum.append(In_Hum[i])
            Clean_In_Temp.append(In_Temp[i])
        else:
            continue
    return Clean_In_Temp, Clean_In_Hum
Clean_In_Temp, Clean_In_Hum = clean_In(In_Temp, In_Temp_Div2, In_Hum, In_Hum_Div2)
# Out:
# /tmp/ipykernel_113/2237414301.py:6: RuntimeWarning: divide by zero encountered in scalar divide
#   In_Hum_Div1.append((In_Hum[i+1]-In_Hum[i])/(In_Temp[i+1]-In_Temp[i]))

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
b=np.corrcoef(In_Temp,In_Hum)
fig.suptitle('Temperature vs. Humidity')
ax1.scatter(In_Temp,In_Hum,label='Inside',s=1,c='b')
ax1.plot(np.arange(2)+In_Temp[0],b[0][1]*np.arange(2)+In_Hum[0],label='Inside Coeff',c='b')
ax1.set_xlabel('Temperature (C)')
ax1.set_ylabel('Humidity')
ax1.legend(bbox_to_anchor=(.25, 1.15))
b2=np.corrcoef(Out_Temp,In_Hum)
ax2.scatter(Out_Temp,Out_Hum,label='Outside',s=1,c='g')
ax2.plot(np.arange(6)+Out_Temp[0],(b2[0][1]*np.arange(6)+Out_Hum[0]),label='Outside Coeff',c='g')
ax2.set_xlabel('Temperature (C)')
ax2.set_ylabel('Humidity')
ax2.legend(bbox_to_anchor=(1.25, 1.15))

# %%
#Temp vs Pressure
Out_Pressure = np.loadtxt('Lab_6_outside.csv', delimiter=',', skiprows=2,usecols=4)
In_Pressure = np.loadtxt('Lab_6_inside.csv', delimiter=',', skiprows=2,usecols=4)

# %%
d=np.corrcoef(In_Temp,In_Pressure)
d2=np.corrcoef(Out_Temp,Out_Pressure)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.suptitle('Temperature vs. Pressure')
ax1.scatter(In_Temp,In_Pressure,label='Inside',s=1,c='b')
ax1.plot(np.arange(2)+In_Temp[0],d[0][1]*np.arange(2)+In_Pressure[0],label='Inside Coeff',c='b')
ax1.set_xlabel('Temperature (C)')
ax1.set_ylabel('Pressure')
ax1.legend(bbox_to_anchor=(.25, 1.15))
ax2.scatter(Out_Temp,Out_Pressure,label='Outside',s=1,c='g')
ax2.plot(np.arange(6)+Out_Temp[0],(d2[0][1]*np.arange(6)+Out_Pressure[0]),label='Outside Coeff',c='g')
ax2.set_xlabel('Temperature (C)')
ax2.set_ylabel('Pressure')
ax2.legend(bbox_to_anchor=(1.25, 1.15))

# %%
#Temp vs. PM2.5
e=np.corrcoef(In_Temp,In_Particles)
e2=np.corrcoef(Out_Temp,Out_Particles)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.suptitle('Temperature vs. PM2.5')
ax1.scatter(In_Temp,In_PM2_5,label='Inside',s=1,c='b')
ax1.plot(np.arange(2)+In_Temp[0],d[0][1]*np.arange(2)+In_PM2_5[0],label='Inside Coeff',c='b')
ax1.set_xlabel('Temperature (C)')
ax1.set_ylabel('PM2_5')
ax1.legend(bbox_to_anchor=(.25, 1.15))
ax2.scatter(Out_Temp,Out_PM2_5,label='Outside',s=1,c='g')
ax2.plot(np.arange(6)+Out_Temp[0],(d[0][1]*np.arange(6)+Out_PM2_5[0]),label='Outside Coeff',c='g')
ax2.set_xlabel('Temperature (C)')
ax2.set_ylabel('PM2_5')
ax2.legend(bbox_to_anchor=(1.25, 1.15))
